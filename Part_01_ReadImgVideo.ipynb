# %%
# !pwd
# Out:
# /home/henry/Desktop/DIP/coding/basic

# %%
# %cd ..
# Out:
# /home/henry/Desktop/DIP/coding

# %%
# !conda install --channel menpo opencv

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Reading Image

# %%
cat_img = cv.imread('img/Photos/cat.jpg')

# %%
print("Type: ", type(cat_img))
print("Image size: ", cat_img.shape)
# Out:
# Type:  <class 'numpy.ndarray'>
# Image size:  (427, 640, 3)

# %%
plt.imshow(cat_img)
plt.show()

# %%
cat_large_img = cv.imread('img/Photos/cat_large.jpg')
RGB_cat_large_img = cv.cvtColor(cat_large_img, cv.COLOR_BGR2RGB)
plt.imshow(RGB_cat_large_img)
plt.show()

# %% [markdown]
# ## 2. Reading Video

# %%
dog_capture = cv.VideoCapture('img/Videos/dog.mp4')
dog_capture
# Out:
# < cv2.VideoCapture 0x7f288beb92b0>

# %%
# count = 0
# while True:
#     isTrue, frame = dog_capture.read()
#     cv.imshow('Dog Video', frame)
#     if cv.waitKey(20) & 0xFF==ord('q'):
#         break
# dog_capture.release()
# cv.destroyAllWindows()
